# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 실제 train data를 변환하기 - 데이터 읽어들이기

import json
import os
import pandas as pd
import numpy as np

base_dir = os.getcwd()

train_images_path = base_dir + '/data/train/images/'
train_labels_json_path = base_dir + '/data/train/labels_json/'
train_labels_path = base_dir + '/data/train/labels/'

os.makedirs(train_images_path, exist_ok=True)
os.makedirs(train_labels_json_path, exist_ok=True)
os.makedirs(train_labels_path, exist_ok=True)

# !unzip -qq '/content/drive/MyDrive/KCC3기_2차_프로젝트/train_v2.zip' -d '/content/data/'

train_images_list = os.listdir(train_images_path)
train_labels_json_list = os.listdir(train_labels_json_path)

train_images_list.sort()
train_labels_json_list.sort()

# %%
# json 라벨 삭제 및 라벨링 확인

import shutil

shutil.rmtree('/content/data/train/labels_json')
shutil.rmtree('/content/data/val/labels_json')

# %%
# 분리한 데이터 이미지와 라벨 파일 일치 여부 확인

print(len(os.listdir('/content/data/train/images/')))
print(len(os.listdir('/content/data/train/labels/')))

print(len(os.listdir('/content/data/val/images/')))
print(len(os.listdir('/content/data/val/labels/')))

train_images_list = os.listdir('/content/data/train/images/')
train_labels_list = os.listdir('/content/data/train/labels/')

train_images_list.sort()
train_labels_list.sort()

for i in range(len(train_images_list)):
  if train_images_list[i].replace('.jpg', '') != train_labels_list[i].replace('.txt', ''):
    print(train_images_list[i])

val_images_list = os.listdir('/content/data/val/images/')
val_labels_list = os.listdir('/content/data/val/labels/')

val_images_list.sort()
val_labels_list.sort()

for i in range(len(val_images_list)):
  if val_images_list[i].replace('.jpg', '') != val_labels_list[i].replace('.txt', ''):
    print(val_images_list[i])
# Out:
# 21068
# 21068
# 2435
# 2435

# %%
# YOLO 학습을 위한 yaml 파일 생성

# !pip install PyYAML

import yaml

data = {
    'train': '/content/data/train/images/',
    'val': '/content/data/val/images',
    'names': ['IronCan_NoDamNoDir', 'IronCan_NoDamDir', 'IronCan_DamNoDir', 'IronCan_DamDir',
              'AluminumCan_NoDamNoDir', 'AluminumCan_NoDamDir', 'AluminumCan_DamNoDir', 'AluminumCan_DamDir',
              'Paper_NoDamNoDir', 'Paper_NoDamDir', 'Paper_DamNoDir', 'Paper_DamDir',
              'PetNoColor_NoDamNoDir', 'PetNoColor_NoDamDir', 'PetNoColor_DamNoDir', 'PetNoColor_DamDir',
              'PetColor_NoDamNoDir', 'PetColor_NoDamDir', 'PetColor_DamNoDir', 'PetColor_DamDir',
              'PE_NoDamNoDir', 'PE_NoDamDir', 'PE_DamNoDir', 'PE_DamDir',
              'PP_NoDamNoDir', 'PP_NoDamDir', 'PP_DamNoDir', 'PP_DamDir',
              'PS_NoDamNoDir', 'PS_NoDamDir', 'PS_DamNoDir', 'PS_DamDir',
              'Styrofoam_NoDamNoDir', 'Styrofoam_NoDamDir', 'Styrofoam_DamNoDir', 'Styrofoam_DamDir',
              'Vinyl_NoDamNoDir', 'Vinyl_NoDamDir', 'Vinyl_DamNoDir', 'Vinyl_DamDir',
              'GlassBrown_NoDamNoDir', 'GlassBrown_NoDamDir', 'GlassBrown_DamNoDir', 'GlassBrown_DamDir',
              'GlassGreen_NoDamNoDir', 'GlassGreen_NoDamDir', 'GlassGreen_DamNoDir', 'GlassGreen_DamDir',
              'GlassTransparency_NoDamNoDir', 'GlassTransparency_NoDamDir', 'GlassTransparency_DamNoDir', 'GlassTransparency_DamDir'],
    'nc': 52
}

yaml_name = 'recycle_data.yaml'
with open('/content/data/' + 'recycle_data.yaml', 'w') as f:
  yaml.dump(data, f)

with open('/content/data/' + 'recycle_data.yaml', 'r') as f:
  recycle_yaml = yaml.safe_load(f)
  display(recycle_yaml)
# Out:
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (6.0.1)
# {'names': ['IronCan_NoDamNoDir',
#   'IronCan_NoDamDir',
#   'IronCan_DamNoDir',
#   'IronCan_DamDir',
#   'AluminumCan_NoDamNoDir',
#   'AluminumCan_NoDamDir',
#   'AluminumCan_DamNoDir',
#   'AluminumCan_DamDir',
#   'Paper_NoDamNoDir',
#   'Paper_NoDamDir',
#   'Paper_DamNoDir',
#   'Paper_DamDir',
#   'PetNoColor_NoDamNoDir',
#   'PetNoColor_NoDamDir',
#   'PetNoColor_DamNoDir',
#   'PetNoColor_DamDir',
#   'PetColor_NoDamNoDir',
#   'PetColor_NoDamDir',
#   'PetColor_DamNoDir',
#   'PetColor_DamDir',
#   'PE_NoDamNoDir',
#   'PE_NoDamDir',
#   'PE_DamNoDir',
#   'PE_DamDir',
#   'PP_NoDamNoDir',
#   'PP_NoDamDir',
#   'PP_DamNoDir',
#   'PP_DamDir',
#   'PS_NoDamNoDir',
#   'PS_NoDamDir',
#   'PS_DamNoDir',
#   'PS_DamDir',
#   'Styrofoam_NoDamNoDir',
#   'Styrofoam_NoDamDir',
#   'Styrofoam_DamNoDir',
#   'Styrofoam_DamDir',
#   'Vinyl_NoDamNoDir',
#   'Vinyl_NoDamDir',
#   'Vinyl_DamNoDir',
#   'Vinyl_DamDir',
#   'GlassBrown_NoDamNoDir',
#   'GlassBrown_NoDamDir',
#   'GlassBrown_DamNoDir',
#   'GlassBrown_DamDir',
#   'GlassGreen_NoDamNoDir',
#   'GlassGreen_NoDamDir',
#   'GlassGreen_DamNoDir',
#   'GlassGreen_DamDir',
#   'GlassTransparency_NoDamNoDir',
#   'GlassTransparency_NoDamDir',
#   'GlassTransparency_DamNoDir',
#   'GlassTransparency_DamDir'],
#  'nc': 52,
#  'train': '/content/data/train/images/',
#  'val': '/content/data/val/images'}

# %%
# YOLO 학습 위한 환경

# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/78.2 GB disk)

# %%
# YOLO 전이 학습
from ultralytics import YOLO
import shutil, os

# model = YOLO('yolov8n.pt')

# model.train(data='/content/data/recycle_data.yaml', epochs=1, patience=3, batch=64, imgsz=640, name='recycle', exist_ok=True)

# if os.path.isdir('/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle'):
#   shutil.rmtree('/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle')

# shutil.copytree('/content/runs/detect/recycle/' , '/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle0/')

# %%
# google drive의 모델 파일을 불러들여 다시 전이 학습
# 학습 완료 시 다시 google drive로 모델 파일 이동

from ultralytics import YOLO
import shutil, os

model_num = 11

# model = YOLO('/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle' + str(model_num) + '/weights/best.pt')

# model_num += 1

# model.train(data='/content/data/recycle_data.yaml', epochs=75, patience=100, batch=64, imgsz=640,
#             name='recycle' + str(model_num), project='/content/drive/MyDrive/KCC_2nd_project/models_v2/', exist_ok=True)
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle10/weights/best.pt, data=/content/data/recycle_data.yaml, epochs=75, patience=100, batch=64, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/KCC_2nd_project/models_v2/, name=recycle11, exist_ok=True, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 17.3MB/s]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    761452  ultralytics.nn.modules.head.Detect           [52, [64, 128, 256]]
# Model summary: 225 layers, 3020988 parameters, 3020972 gradients
#
# Transferred 355/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 80.5MB/s]
# AMP: checks passed ✅
# train: Scanning /content/data/train/labels... 21068 images, 0 backgrounds, 0 corrupt: 100%|██████████| 21068/21068 [00:37<00:00, 555.84it/s]
# train: New cache created: /content/data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/data/val/labels... 2435 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2435/2435 [00:03<00:00, 805.58it/s]
# val: New cache created: /content/data/val/labels.cache
# Plotting labels to /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11
# Starting training for 75 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/75      9.35G     0.4559     0.7053     0.9754         38        640: 100%|██████████| 330/330 [07:58<00:00,  1.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:34<00:00,  1.72s/it]
#                    all       2435       3044      0.788      0.747      0.815       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/75      8.64G     0.4707     0.7197     0.9779         24        640: 100%|██████████| 330/330 [07:50<00:00,  1.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:35<00:00,  1.75s/it]
#                    all       2435       3044      0.724        0.7       0.76      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/75      8.65G     0.5257     0.8761      1.003         19        640: 100%|██████████| 330/330 [07:40<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:33<00:00,  1.67s/it]
#                    all       2435       3044      0.568      0.621      0.611      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/75      8.64G     0.5832      1.077      1.032         32        640: 100%|██████████| 330/330 [07:37<00:00,  1.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.57s/it]
#                    all       2435       3044      0.527       0.57      0.541      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/75      8.65G     0.5912      1.095      1.037         29        640: 100%|██████████| 330/330 [07:46<00:00,  1.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:32<00:00,  1.62s/it]
#                    all       2435       3044      0.618      0.591      0.644      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/75      8.64G     0.5878      1.091      1.035         33        640: 100%|██████████| 330/330 [07:45<00:00,  1.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:32<00:00,  1.60s/it]
#                    all       2435       3044      0.595      0.588      0.623      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/75      8.65G     0.5863      1.086      1.034         26        640: 100%|██████████| 330/330 [07:45<00:00,  1.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.57s/it]
#                    all       2435       3044      0.584      0.571      0.596      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/75      8.64G     0.5838      1.069      1.032         39        640: 100%|██████████| 330/330 [07:48<00:00,  1.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:33<00:00,  1.68s/it]
#                    all       2435       3044      0.565      0.605      0.618      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/75      8.65G     0.5848       1.05      1.034         28        640: 100%|██████████| 330/330 [07:43<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:35<00:00,  1.77s/it]
#                    all       2435       3044      0.629      0.582      0.632      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/75      8.65G     0.5768      1.034       1.03         26        640: 100%|██████████| 330/330 [07:43<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:32<00:00,  1.64s/it]
#                    all       2435       3044      0.557      0.594      0.605      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/75      8.73G      0.572       1.02      1.026         24        640: 100%|██████████| 330/330 [07:44<00:00,  1.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:30<00:00,  1.55s/it]
#                    all       2435       3044      0.668      0.672      0.704      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/75      8.59G     0.5679      1.021      1.023         26        640: 100%|██████████| 330/330 [07:45<00:00,  1.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.59s/it]
#                    all       2435       3044      0.647      0.651      0.683      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/75      8.59G     0.5624      1.001      1.021         30        640: 100%|██████████| 330/330 [07:55<00:00,  1.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:33<00:00,  1.65s/it]
#                    all       2435       3044       0.68       0.63      0.694      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/75      8.65G     0.5667     0.9754      1.024         23        640: 100%|██████████| 330/330 [07:49<00:00,  1.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.57s/it]
#                    all       2435       3044      0.679      0.666      0.716      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/75      8.64G     0.5602     0.9812      1.021         26        640: 100%|██████████| 330/330 [07:54<00:00,  1.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.58s/it]
#                    all       2435       3044      0.675      0.659      0.709      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/75      8.64G     0.5549     0.9605      1.018         29        640: 100%|██████████| 330/330 [07:52<00:00,  1.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.59s/it]
#                    all       2435       3044      0.676      0.684      0.727      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/75      8.65G     0.5508     0.9557      1.017         27        640: 100%|██████████| 330/330 [07:50<00:00,  1.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.58s/it]
#                    all       2435       3044      0.702      0.692      0.748      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/75      8.65G      0.547     0.9361      1.014         30        640: 100%|██████████| 330/330 [07:48<00:00,  1.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.56s/it]
#                    all       2435       3044      0.709       0.69      0.739      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/75      8.65G     0.5455     0.9358      1.013         24        640: 100%|██████████| 330/330 [07:45<00:00,  1.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:30<00:00,  1.54s/it]
#                    all       2435       3044      0.719      0.701       0.76      0.708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/75      8.65G     0.5418     0.9286      1.012         29        640: 100%|██████████| 330/330 [07:42<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:32<00:00,  1.63s/it]
#                    all       2435       3044       0.75      0.705      0.773      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/75      8.62G     0.5415     0.9083      1.012         18        640: 100%|██████████| 330/330 [07:40<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:30<00:00,  1.53s/it]
#                    all       2435       3044      0.763      0.699      0.775       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/75      8.64G     0.5334     0.9073      1.009         31        640: 100%|██████████| 330/330 [07:37<00:00,  1.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:33<00:00,  1.65s/it]
#                    all       2435       3044      0.746       0.73      0.784      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/75      8.65G     0.5347     0.9025       1.01         20        640: 100%|██████████| 330/330 [07:40<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.57s/it]
#                    all       2435       3044      0.737      0.735      0.789      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/75      8.65G     0.5349     0.8852      1.009         26        640: 100%|██████████| 330/330 [07:40<00:00,  1.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:32<00:00,  1.61s/it]
#                    all       2435       3044      0.771        0.7      0.785      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/75      8.67G     0.5288      0.879      1.004         30        640: 100%|██████████| 330/330 [07:40<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.56s/it]
#                    all       2435       3044      0.766       0.73      0.786      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/75      8.59G     0.5243     0.8705      1.003         27        640: 100%|██████████| 330/330 [07:40<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:31<00:00,  1.56s/it]
#                    all       2435       3044      0.734      0.743      0.796      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/75      8.64G     0.5232     0.8649     0.9997         40        640: 100%|██████████| 330/330 [07:40<00:00,  1.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:33<00:00,  1.69s/it]
#                    all       2435       3044      0.767      0.747      0.812      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/75      8.62G     0.5193      0.849      1.003        162        640:  80%|████████  | 265/330 [06:11<01:40,  1.55s/it]Exception in thread Thread-12:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py", line 244, in run
#     self._run()
#   File "/usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py", line 289, in _run
#     self._record_writer.flush()
#   File "/usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/record_writer.py", line 43, in flush
#     self._writer.flush()
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/lib/io/file_io.py", line 221, in flush
#     self._writable_file.flush()
# tensorflow.python.framework.errors_impl.FailedPreconditionError: /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11/events.out.tfevents.1692926007.b7994a4a1dfe.703.0; Transport endpoint is not connected
#       28/75      8.62G     0.5191      0.849      1.003        149        640:  80%|████████  | 265/330 [06:11<01:31,  1.40s/it]
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-8-355eadd20ede> in <cell line: 13>()
#      11 model_num += 1
#      12
# ---> 13 model.train(data='/content/data/recycle_data.yaml', epochs=75, patience=100, batch=64, imgsz=640,
#      14             name='recycle' + str(model_num), project='/content/drive/MyDrive/KCC_2nd_project/models_v2/', exist_ok=True)
#      15
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     375             self.model = self.trainer.model
#     376         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 377         self.trainer.train()
#     378         # Update model and cfg after training
#     379         if RANK in (-1, 0):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in train(self)
#     192                 ddp_cleanup(self, str(file))
#     193         else:
# --> 194             self._do_train(world_size)
#     195
#     196     def _setup_ddp(self, world_size):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     371                         ('%11s' * 2 + '%11.4g' * (2 + loss_len)) %
#     372                         (f'{epoch + 1}/{self.epochs}', mem, *losses, batch['cls'].shape[0], batch['img'].shape[-1]))
# --> 373                     self.run_callbacks('on_batch_end')
#     374                     if self.args.plots and ni in self.plot_idx:
#     375                         self.plot_training_samples(batch, ni)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in run_callbacks(self, event)
#     165         """Run all existing callbacks associated with a particular event."""
#     166         for callback in self.callbacks.get(event, []):
# --> 167             callback(self)
#     168
#     169     def train(self):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/utils/callbacks/tensorboard.py in on_batch_end(trainer)
#      61 def on_batch_end(trainer):
#      62     """Logs scalar statistics at the end of a training batch."""
# ---> 63     _log_scalars(trainer.label_loss_items(trainer.tloss, prefix='train'), trainer.epoch + 1)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/utils/callbacks/tensorboard.py in _log_scalars(scalars, step)
#      20     if WRITER:
#      21         for k, v in scalars.items():
# ---> 22             WRITER.add_scalar(k, v, step)
#      23
#      24
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/writer.py in add_scalar(self, tag, scalar_value, global_step, walltime, new_style, double_precision)
#     389             tag, scalar_value, new_style=new_style, double_precision=double_precision
#     390         )
# --> 391         self._get_file_writer().add_summary(summary, global_step, walltime)
#     392
#     393     def add_scalars(self, main_tag, tag_scalar_dict, global_step=None, walltime=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/writer.py in add_summary(self, summary, global_step, walltime)
#     111         """
#     112         event = event_pb2.Event(summary=summary)
# --> 113         self.add_event(event, global_step, walltime)
#     114
#     115     def add_graph(self, graph_profile, walltime=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/writer.py in add_event(self, event, step, walltime)
#      96             # since protobuf might not convert depending on version
#      97             event.step = int(step)
# ---> 98         self.event_writer.add_event(event)
#      99
#     100     def add_summary(self, summary, global_step=None, walltime=None):
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py in add_event(self, event)
#     115                 " but got %s" % type(event)
#     116             )
# --> 117         self._async_writer.write(event.SerializeToString())
#     118
#     119     def flush(self):
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py in write(self, bytestring)
#     169             # multiple threads passing the check and then switching just before
#     170             # blocking on putting to the queue which might result in a deadlock.
# --> 171             self._check_worker_status()
#     172             if self._closed:
#     173                 raise IOError("Writer is closed")
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py in _check_worker_status(self)
#     210         exception = self._worker.exception
#     211         if exception is not None:
# --> 212             raise exception
#     213
#     214
#
# /usr/lib/python3.10/threading.py in _bootstrap_inner(self)
#    1014
#    1015             try:
# -> 1016                 self.run()
#    1017             except:
#    1018                 self._invoke_excepthook(self)
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py in run(self)
#     242     def run(self):
#     243         try:
# --> 244             self._run()
#     245         except Exception as ex:
#     246             self.exception = ex
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/event_file_writer.py in _run(self)
#     287                     # there's no need to flush, since each flush can be
#     288                     # expensive (e.g. uploading a new file to a server).
# --> 289                     self._record_writer.flush()
#     290                     self._has_pending_data = False
#     291                 # Do it again in flush_secs.
#
# /usr/local/lib/python3.10/dist-packages/tensorboard/summary/writer/record_writer.py in flush(self)
#      41
#      42     def flush(self):
# ---> 43         self._writer.flush()
#      44
#      45     def close(self):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/lib/io/file_io.py in flush(self)
#     219     """
#     220     if self._writable_file:
# --> 221       self._writable_file.flush()
#     222
#     223   def close(self):
#
# FailedPreconditionError: /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11/events.out.tfevents.1692926007.b7994a4a1dfe.703.0; Transport endpoint is not connected

# %%
# 연결이 끊기면 끊긴 곳에서부터 재학습

from ultralytics import YOLO
import shutil, os

model_num = 11

model = YOLO('/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle' + str(model_num) + '/weights/last.pt')

model.train(resume=1)
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11/weights/last.pt, data=/content/data/recycle_data.yaml, epochs=75, patience=100, batch=64, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/KCC_2nd_project/models_v2/, name=recycle11, exist_ok=True, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11', view at http://localhost:6006/
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    761452  ultralytics.nn.modules.head.Detect           [52, [64, 128, 256]]
# Model summary: 225 layers, 3020988 parameters, 3020972 gradients
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/data/train/labels.cache... 21068 images, 0 backgrounds, 0 corrupt: 100%|██████████| 21068/21068 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/data/val/labels.cache... 2435 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2435/2435 [00:00<?, ?it/s]
# Plotting labels to /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Resuming training from /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11/weights/last.pt from epoch 63 to 75 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/KCC_2nd_project/models_v2/recycle11
# Starting training for 75 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/75      9.36G     0.4059     0.5302     0.9508        129        640:   5%|▌         | 17/330 [00:30<09:27,  1.81s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-507d087fa389> in <cell line: 10>()
#       8 model = YOLO('/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle' + str(model_num) + '/weights/last.pt')
#       9
# ---> 10 model.train(resume=1)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     375             self.model = self.trainer.model
#     376         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 377         self.trainer.train()
#     378         # Update model and cfg after training
#     379         if RANK in (-1, 0):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in train(self)
#     192                 ddp_cleanup(self, str(file))
#     193         else:
# --> 194             self._do_train(world_size)
#     195
#     196     def _setup_ddp(self, world_size):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     360                 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#     361                 if ni - last_opt_step >= self.accumulate:
# --> 362                     self.optimizer_step()
#     363                     last_opt_step = ni
#     364
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in optimizer_step(self)
#     480         """Perform a single step of the training optimizer with gradient clipping and EMA update."""
#     481         self.scaler.unscale_(self.optimizer)  # unscale gradients
# --> 482         torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)  # clip gradients
#     483         self.scaler.step(self.optimizer)
#     484         self.scaler.update()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/clip_grad.py in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite, foreach)
#      74     for ((device, _), [grads]) in grouped_grads.items():
#      75         if (foreach is None or foreach) and _has_foreach_support(grads, device=device):
# ---> 76             torch._foreach_mul_(grads, clip_coef_clamped.to(device))  # type: ignore[call-overload]
#      77         elif foreach:
#      78             raise RuntimeError(f'foreach=True was passed, but can\'t use the foreach API on {device.type} tensors')
#
# KeyboardInterrupt:

# %%
# 예측 값 확인

from ultralytics import YOLO
import shutil, os
from PIL import Image
import matplotlib.pyplot as plt

model_num = 0

model = YOLO('/content/drive/MyDrive/KCC_2nd_project/models_v2/recycle'+ str(model_num) + '/weights/best.pt')

for i in range(10):
  results = model('/content/data/val/images/' + os.listdir('/content/data/val/images/')[i])

  # Show the results
  for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    plt.imshow(im)
    plt.show()
